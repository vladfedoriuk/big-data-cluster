# %%
from operator import add

from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession
    .builder
    .appName("pyspark-notebook")
    .master("spark://spark-master:7077")
    .config("spark.executor.memory", "512m")
    .getOrCreate()
)

# %%
# https://www.gutenberg.org/cache/epub/1513/pg1513.txt
import string
import re

lines = spark.read.text("hdfs://namenode:9000/pg1513.txt").rdd.map(lambda r: r[0])
counts = (
    lines
    .flatMap(lambda x: x.split(' '))
    .map(lambda x: x.lower())
    .map(lambda x: x.strip())
    .map(lambda x: x.replace(string.punctuation, ''))
    .map(lambda x: re.sub(r'[^\w\s]', '', x))
    .filter(lambda x: len(x) > 0)
    .map(lambda x: (x, 1))
    .reduceByKey(add)
)
output = counts.collect()
for (word, count) in output:
    print("%s: %i" % (word, count))
# Out:
# the: 875
# project: 89
# gutenberg: 32
# ebook: 13
# of: 518
# romeo: 301
# and: 803
# juliet: 180
# by: 142
# william: 3
# shakespeare: 4
# this: 265
# is: 366
# for: 249
# use: 26
# anyone: 5
# anywhere: 3
# in: 393
# united: 15
# states: 20
# most: 22
# other: 33
# parts: 4
# world: 17
# at: 83
# no: 111
# cost: 4
# with: 299
# almost: 5
# restrictions: 2
# whatsoever: 2
# you: 362
# may: 64
# copy: 12
# it: 242
# give: 51
# away: 25
# or: 144
# reuse: 2
# under: 12
# terms: 23
# license: 17
# included: 3
# online: 4
# wwwgutenbergorg: 5
# if: 106
# are: 89
# not: 288
# located: 7
# will: 156
# have: 133
# to: 622
# check: 4
# laws: 10
# country: 5
# where: 56
# before: 24
# using: 6
# title: 2
# author: 1
# release: 1
# date: 6
# november: 1
# 1998: 1
# 1513: 1
# recently: 1
# updated: 2
# 11: 1
# 2022: 1
# language: 2
# english: 1
# produced: 2
# pg: 2
# team: 3
# a: 541
# about: 20
# twenty: 11
# volunteers: 6
# start: 3
# tragedy: 1
# contents: 1
# prologue: 3
# act: 13
# ...

# %%
# https://www.gutenberg.org/cache/epub/1513/pg1513.txt
import string
import re

lines = spark.read.text("hdfs://namenode:9000/t*.txt").rdd.map(lambda r: r[0])
counts = (
    lines
    .flatMap(lambda x: x.split(' '))
    .map(lambda x: x.lower())
    .map(lambda x: x.strip())
    .map(lambda x: x.replace(string.punctuation, ''))
    .map(lambda x: re.sub(r'[^\w\s]', '', x))
    .filter(lambda x: len(x) > 0)
    .map(lambda x: (x, 1))
    .reduceByKey(add)
)
output = counts.collect()
for (word, count) in output:
    print("%s: %i" % (word, count))
# Out:
# zzz: 1
# aaa: 1
# abc: 3
# eee: 1
# ccc: 1
# ddd: 2
# xyz: 1
