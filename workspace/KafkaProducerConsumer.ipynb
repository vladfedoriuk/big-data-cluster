# %%
# !pip install aiokafka==0.8.1 pydantic==1.10.9 httpx==0.24.1 vcrpy==4.3.1 tenacity==8.2.2
# Out:
# Collecting aiokafka==0.8.1
#   Downloading aiokafka-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting pydantic==1.10.9
#   Downloading pydantic-1.10.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 6.1 MB/s eta 0:00:0000:0100:01
# Collecting httpx==0.24.1
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 2.3 MB/s eta 0:00:00
# Collecting vcrpy==4.3.1
#   Downloading vcrpy-4.3.1-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.4 MB/s eta 0:00:00
# Collecting tenacity==8.2.2
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting async-timeout (from aiokafka==0.8.1)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting kafka-python>=2.0.2 (from aiokafka==0.8.1)
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 6.6 MB/s eta 0:00:0000:01
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from aiokafka==0.8.1) (23.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic==1.10.9) (4.6.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx==0.24.1) (2023.5.7)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx==0.24.1)
#   Downloading httpcore-0.17.2-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: idna in /opt/conda/lib/python3.10/site-packages (from httpx==0.24.1) (3.4)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx==0.24.1) (1.3.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from vcrpy==4.3.1) (6.0)
# Collecting wrapt (from vcrpy==4.3.1)
#   Downloading wrapt-1.15.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from vcrpy==4.3.1) (1.16.0)
# Collecting yarl (from vcrpy==4.3.1)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 5.4 MB/s eta 0:00:00a 0:00:01
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx==0.24.1)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/conda/lib/python3.10/site-packages (from httpcore<0.18.0,>=0.15.0->httpx==0.24.1) (3.6.2)
# Collecting multidict>=4.0 (from yarl->vcrpy==4.3.1)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 2.2 MB/s eta 0:00:0000:01
# Installing collected packages: kafka-python, wrapt, tenacity, pydantic, multidict, h11, async-timeout, yarl, httpcore, aiokafka, vcrpy, httpx
# Successfully installed aiokafka-0.8.1 async-timeout-4.0.2 h11-0.14.0 httpcore-0.17.2 httpx-0.24.1 kafka-python-2.0.2 multidict-6.0.4 pydantic-1.10.9 tenacity-8.2.2 vcrpy-4.3.1 wrapt-1.15.0 yarl-1.9.2

# %%
from typing import Final

# https://tenders.guru/pl/api
BASE_URL: Final[str] = "https://tenders.guru/api/pl/tenders"

# %%
from pydantic import BaseModel, Field
import datetime

class TendersQueryParams(BaseModel):
    page: int

class TenderDetail(BaseModel):
    id: int
    date: datetime.date
    title: str = ""
    description: str = ""

class TendersListResponse(BaseModel):
    page_count: int
    page_number: int
    page_size: int
    total: int
    data: list[TenderDetail] = Field(default_factory=list)

# %%
import httpx
import tenacity

@tenacity.retry(
    wait=tenacity.wait_exponential(multiplier=1, min=4, max=10),
    stop=tenacity.stop_after_attempt(5),
)
async def get_tenders_list(client_: httpx.AsyncClient, page: int) -> TendersListResponse:
    response = await client_.get(
        BASE_URL,
        params=TendersQueryParams(page=page).dict(),
    )
    response.raise_for_status()
    return TendersListResponse.parse_obj(response.json())

# %%
import httpx

timeout = httpx.Timeout(10.0, connect=60.0)
limits = httpx.Limits(max_keepalive_connections=5, max_connections=10)
client = httpx.AsyncClient(timeout=timeout, limits=limits)

# %%
await get_tenders_list(client, 1)
# Out:
# TendersListResponse(page_count=5843, page_number=1, page_size=100, total=584242, data=[TenderDetail(id=586940, date=datetime.date(2023, 5, 3), title='Dostawa odczynników i testów. Część 1-5', description='Przedmiotem zamówienia jest: dostawa odczynników i testów w projekcie pt.: „Wdrożenie innowacyjnych elementów technologicznych w procesie wylęgu kaczek w celu ograniczenia zagrożeń mikrobiologicznych i poprawy jakości zdrowotnej i dobrostanu lężonych piskląt” z podziałem na części:\nCzęść nr 1: VA2 grupa 1a odczynniki do badań molekularnych\nCzęść nr 2: VA2 grupa 1b odczynniki do badań molekularnych – startery\nCzęść nr 3: VA2 grupa 2 odczynniki do elektroforezy\nCzęść nr 4: VA2 grupa 3 testy lekoop'), TenderDetail(id=586948, date=datetime.date(2023, 5, 3), title='Dostawa licencji IBM wraz z 12 miesięcznym wsparciem technicznym producenta', description='1. Przedmiotem zamówienia jest dostawa licencji wraz z zapewnieniem 12 miesięcznego wsparcia technicznego Producenta dla:\n1.1. IBM Db2 Standard Edition Cartridge for IBM Cloud Pak for Data Virtual Processor Core License + SW Subscription &amp; Support 12 Months “lub równoważnym” – 60 sztuk;\n1.2. IBM Db2 Advanced Edition AU Option for Non-Production Environments Authorized User License + SW Subscription &amp; Support 12 Months “lub równoważnym” – 8 sztuk;\n1.3. IBM WebSphere Hybrid Edition Virtual'), TenderDetail(id=585088, date=datetime.date(2022, 11, 23), title='Dostawa sprzętu medycznego dla potrzeb Uzdrowiska Goczałkowice - Zdrój Sp. z o.o. z siedzibą w Goczałkowicach - Zdroju', description='W zakres zamówienia wchodzi kolumna wolnostojąca do progresywnego treningu oporowego dla rehabilitacji pourazowej – 1 szt.'), TenderDetail(id=583899, date=datetime.date(2022, 11, 16), title='Zakup wyposażenia do Centrum Opiekuńczo Mieszkalnego w Kętrzynie przy ul. Sikorskiego 46 (3).', description='Dostawa wyposażenia kuchennego i sprzętu AGD.Zamówienie obejmuje m.in.: talerze, kubki, szklanki, patelnie, sztućce, garnki, akcesoria kuchenne, mikrofalówki, termosy stalowe, podgrzewacze, kociołki elektryczne, lodówka, czajniki, itp.Szczegółowy opis zamówienia znajduje się w Załączniku nr 1a dla Części 1.'), TenderDetail(id=584049, date=datetime.date(2022, 4, 21), title='Dostawa artykułów żywnościowych do stołówki szkolnej od maja do grudnia 2022r .', description='Zakup i dostawa artykułów ogólnospożywczych ( wykaz ilościowy załącznik nr 1 SWZ )'), TenderDetail(id=587527, date=datetime.date(2022, 11, 9), title='Zimowe utrzymanie dróg w sezonie zimowym 2022/2023 (II postępowanie)', description='1. Część 1 (zadanie I) - zimowe utrzymanie dróg gminnych : Tropie i Roztoka Brzeziny.2. Przedmiot zamówienia obejmuje usługę zimowego utrzymania dróg (odśnieżanie i usuwania śliskości) w miejscowościach: Tropie i Roztoka Brzeziny o łącznej długości 34,38 km. 3. Szczegółowy zakres wykonania usługi określone został w następujących w załącznikach do SWZ: a. Załącznik Nr 4a - Zasady zimowego utrzymania dróg gminnychb. Załącznik nr 4c – wykaz dróg gminnych przewidzianych do zimowego utrzymaniac. Załą'), TenderDetail(id=585093, date=datetime.date(2022, 10, 25), title='Sukcesywna dostawa pasty do powlekania', description='3.1. Przedmiotem zamówienia jest sukcesywna dostawa pasty do powlekania w ilości 20 000 kg. Wodna dyspersja niejonowych wypełniaczy i polimerów o parametrach:3.1.1. pH 7,5 ÷ 8,53.1.2. gęstość 20° C 0,9 ÷ 1,1 g/cm33.1.3. Zamawiający wymaga system zachowania jakości lub świadectwo jakości dostawy.3.2. Wspólny Słownik Zamówień CPV24.50.00.00.-9 Tworzywa sztuczne w formach podstawowych3.3. Zamawiający informuje, że przedmiot zamówienia nie został podzielony na części. Wobec powyższego Zamawiający ni'), TenderDetail(id=583014, date=datetime.date(2022, 11, 16), title='ŚWIADCZENIE USŁUGI OCHRONY OSÓB, MIENIA I OBIEKTÓW PROKURATURY REGIONALNEJ W GDAŃSKU', description='1. Przedmiotem zamówienia jest „ŚWIADCZENIE USŁUGI OCHRONY OSÓB, MIENIA I OBIEKTÓW PROKURATURY REGIONALNEJ W GDAŃSKU”.2 Wykonawca  ...

# %%
import vcr
import httpx
from aiokafka import AIOKafkaProducer
import asyncio


async def iterate_over_tenders():
    page = 1
    async with httpx.AsyncClient(timeout=timeout, limits=limits):
        while True:
            try:
                tenders: TendersListResponse = await get_tenders_list(client, page)
            except httpx.HTTPStatusError as e:
                if e.response.status_code == 404:
                    break
                else:
                    raise
            if not (tenders.page_size and tenders.data):
                break
            for tender in tenders.data:
                yield tender
            await asyncio.sleep(1)
            page += 1

def serialize_tender(tender: TenderDetail) -> bytes:
    return tender.json().encode("utf-8")

async def produce_tenders():
    producer = AIOKafkaProducer(
        bootstrap_servers="broker:9092",
        value_serializer=serialize_tender,
    )
    await producer.start()
    try:
        async for tender in iterate_over_tenders():
            await producer.send_and_wait("test", tender)
    finally:
        await producer.stop()

with vcr.use_cassette("work/tenders.yaml", record_mode="new_episodes"):
    await produce_tenders()

# %%
from aiokafka import AIOKafkaConsumer

async def consume_tenders():
    consumer = AIOKafkaConsumer(
        "test",
        bootstrap_servers="broker:9092",
        value_deserializer=TenderDetail.parse_raw,
        auto_offset_reset="earliest",
    )
    await consumer.start()
    try:
        async for tender in consumer:
            print(tender.value)
    finally:
        await consumer.stop()


await consume_tenders()
